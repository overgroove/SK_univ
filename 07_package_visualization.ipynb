# %% [markdown]
# # Visualization (시각화)
# > 데이터분석 및 보고에 필요한 시각화 패키지를 알아보고 실제 데이터로 시각화 예제를 다루어봅니다.
# 데이터 시각화는 데이터분석 과정에서 단순히 데이터를 살펴보는데 그치지 않고 다양한 분석 가능성을 보여줍니다.
# 또한 3자에게 설명을 함에 있어서도 데이터시각화는 굉장히 설득력있는 리포팅을 가능하게 해줍니다.

# %% [markdown]
# ## **Matplotlib**
# > 파이썬의 대표적인 시각화 패키지
# 패키지의 이름에서 느껴지듯 MATLAB의 수리데이터 시각화를 파이썬으로 옮겨온 컨셉
# 기본적인 형태의 다양한 시각화 함수를 제공
# 사용이 약간은 불편

# %% [markdown]
# ### matplotlib 설치 및 불러오기

# %%
# !pip install matplotlib
# matlab 사용자의 시각화 도구 사용가능
# 분석에 사용가능한 여러가지 시각화 함수를 제공합니다. 보통 plt라는 예명으로 사용합니다.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline 
# 주피터 노트북에 최적화 된 그래프 설정(코랩 사용불가)

# %matplotlib notebook 
# 인터렉티브 그래프 가능(코랩 사용불가)

# %% [markdown]
# ### 시각화 한글 폰트 사용

# %%
# 코랩
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 런타임 재시작

# %% [markdown]
# ### 네이버에서 배포하는 나눔바른고딕체 설치 필요
# [https://hangeul.naver.com/font](https://hangeul.naver.com/font)

# %%
plt.rc('font', family='NanumBarunGothic')
# family 파라메터에 사용가능한 폰트이름 전달

# %%
# 사용가능한 폰트 목록 확인
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
# Out:
# ['/Library/Fonts/Skia.ttf',
#  '/Library/Fonts/msgothic.ttc',
#  '/Library/Fonts/AdobeHebrew-BoldItalic.otf',
#  '/Library/Fonts/AppleGothic.ttf',
#  '/Library/Fonts/ArnoPro-BoldItalicCaption_0.otf',
#  '/Library/Fonts/YuGothM.ttc',
#  '/Library/Fonts/REFSPCL.TTF',
#  '/System/Library/Fonts/Thonburi.ttc',
#  '/Library/Fonts/Comic Sans MS Bold.ttf',
#  '/Library/Fonts/Seravek.ttc',
#  '/Library/Fonts/ariali.ttf',
#  '/Library/Fonts/[윤디자인] 윤고딕_9.TTF',
#  '/Library/Fonts/CALIFR.TTF',
#  '/System/Library/Fonts/ヒラギノ角ゴシック W3.ttc',
#  '/Library/Fonts/24520.ttf',
#  '/Library/Fonts/BSSYM7_1.TTF',
#  '/Library/Fonts/11467.ttf',
#  '/Library/Fonts/PTSans.ttc',
#  '/Library/Fonts/Raanana.ttc',
#  '/Library/Fonts/BRLNSDB.TTF',
#  '/Library/Fonts/angsau.ttf',
#  '/Library/Fonts/[윤디자인] 윤고딕_1.TTF',
#  '/Library/Fonts/ITFDevanagari.ttc',
#  '/Library/Fonts/12543.ttf',
#  '/Library/Fonts/AmericanTypewriter.ttc',
#  '/Library/Fonts/AV_____S_0.TTF',
#  '/Library/Fonts/CALIFI.TTF',
#  '/Library/Fonts/PAPYRUS.TTF',
#  '/Library/Fonts/TCCB____.TTF',
#  '/System/Library/Fonts/GeezaPro.ttc',
#  '/Library/Fonts/ARLRDBD_1.TTF',
#  '/Library/Fonts/OLDENGL.TTF',
#  '/Library/Fonts/[윤디자인] 윤고딕_8.TTF',
#  '/Library/Fonts/seguisli.ttf',
#  '/Library/Fonts/13729.ttf',
#  '/System/Library/Fonts/NotoNastaliq.ttc',
#  '/Library/Fonts/micross.ttf',
#  '/Library/Fonts/ENBERNF.TTF',
#  '/Library/Fonts/14506.ttf',
#  '/System/Library/Fonts/PingFang.ttc',
#  '/Library/Fonts/RAGE.TTF',
#  '/Library/Fonts/ANTOB__S_0.TTF',
#  '/Library/Fonts/comicbd_0.ttf',
#  '/Library/Fonts/albr55w_0.ttf',
#  '/Library/Fonts/ALBMTL_S.TTF',
#  '/Library/Fonts/ITFDevanagari.ttc',
#  '/System/Library/Fonts/PingFang.ttc',
#  '/System/Library/Fonts/ArabicUIDisplay.ttc',
#  '/System/Library/Fonts/SFNSDisplay-RegularItalic.otf',
#  '/Library/Fonts/ArnoPro-Caption.otf',
#  '/Library/Fonts/Cochin.ttc',
#  '/Library/Fonts/KoPubBatangMedium.ttf',
#  '/Library/Fonts/[윤디자인] 윤고딕_0.TTF',
#  '/Library/Fonts/ARLRDBD.TTF',
#  '/Library/Fonts/ACaslonPro-Semibold_0.otf',
#  '/Library/Fonts/ArnoPro-BoldSubhead.otf',
#  '/Library/Fonts/browauz.ttf',
#  '/Library/Fonts/91846.ttf',
#  '/Library/Fonts/ACaslonPro-Semibold.otf',
#  '/System/Library/Fonts/HelveticaNeue.ttc',
#  '/System/Library/Fonts/Avenir.ttc',
#  '/Library/Fonts/ArnoPro-SmbdDisplay_0.otf',
#  '/Library/Fonts/YuGothR.ttc',
#  '/Library/Fonts/94029.ttf',
#  '/Library/Fonts/92642.ttf',
#  '/Library/Fonts/92501.ttf',
#  '/Library/Fonts/mmrtext.ttf',
#  '/System/Library/Fonts/Kohinoor.ttc',
#  '/Library/Fonts/Gurmukhi MN.ttc',
#  '/Library/Fonts/Hoefler Text.ttc',
#  '/Library/Fonts/SCHLBKB.TTF',
#  '/Library/Fonts/COR____S.TTF',
#  '/Library/Fonts/50416.TTF',
#  '/Library/Fonts/CharlemagneStd-Bold_0.otf',
#  '/Library/Fonts/BROADW_0.TTF',
#  '/Library/Fonts/Farah.ttc',
#  '/Library/Fonts/ITFDevanagari.ttc',
#  '/Library/Fonts/JOKERMAN.TTF',
#  '/Library/Fonts/ctsb.ttf',
#  '/Library/Fonts/CLE____S.TTF',
#  '/System/Library/Fonts/SFCompactText-LightItalic.otf',
#  '/Library/Fonts/[윤디자인] 윤고딕_A.TTF',
#  '/Library/Fonts/comicz_0.ttf',
#  '/System/Library/Fonts/KohinoorBangla.ttc',
#  '/Library/Fonts/ACaslonPro-Semibold_1.otf',
#  '/Library/Fonts/ctrm.ttf',
#  '/System/Library/Fonts/Avenir Next.ttc',
#  '/Library/Fonts/MOD20.TTF',
#  '/System/Library/Fonts/PingFang.ttc',
#  '/Library/Fonts/Bodoni 72 OS.ttc',
#  '/System/Library/Fonts/Optima.ttc',
#  '/Library/Fonts/Seravek.ttc',
#  '/Library/Fonts/SitkaB.ttc',
#  '/Library/Fonts/segoeuib.ttf',
#  '/Library/Fonts/11547.ttf',
#  '/Library/Fonts/013_0.TTF',
#  '/Library/Fonts/TektonPro-BoldExt.otf',
#  '/Library/Fonts/timesi.ttf',
#  '/Library/Fonts/Damascus.ttc',
#  '/Library/Fonts/BROADW_1.TTF',
#  '/Library/Fonts/framd.ttf',
#  '/Library/Fonts/ARIALNB.TTF',
#  '/Library/Fonts/Myanmar Sangam MN.ttc',
#  '/Library/Fonts/Tahoma Bold.ttf',
#  '/System/Library/Fonts/HelveticaNeue.ttc',
#  '/Library/Fonts/ANTO___S_0.TTF',
#  '/Library/Fonts/consolai.ttf',
#  '/Library/Fonts/ctrmbi.ttf',
#  '/Library/Fonts/PTSerif.ttc',
#  '/Library/Fonts/calibrii_0.ttf',
#  '/System/Library/Fonts/ArialHB.ttc',
#  '/System/Library/Fonts/STHeiti Medium.ttc',
#  '/Library/Fonts/LSANS.TTF',
#  '/Library/Fonts/ArnoPro-Caption_0.otf',
#  '/Library/Fonts/BOD_CI_1.TTF',
#  '/Library/Fonts/MJ.TTF',
#  '/Library/Fonts/SukhumvitSet.ttc',
#  '/Library/Fonts/constan_0.ttf',
#  '/System/Library/Fonts/ArabicUIText.ttc',
#  '/Library/Fonts/SignPainter.ttc',
#  '/System/Library/Fonts/Optima.ttc',
#  '/System/Library/Fonts/ヒラギノ角ゴシック W9.ttc',
#  '/Library/Fonts/calibrib.ttf',
#  '/Library/Fonts/SukhumvitSet.ttc',
#  '/Library/Fonts/MinionPro-Bold.otf',
#  '/Library/Fonts/12511.ttf',
#  '/System/Library/Fonts/Avenir Next.ttc',
#  '/Library/Fonts/OratorStd.otf',
#  '/System/Library/Fonts/AppleSDGothicNeo.ttc',
#  '/Library/Fonts/Seravek.ttc',
#  '/Library/Fonts/12545.ttf',
#  '/Library/Fonts/MyriadPro-BoldIt.otf',
#  '/Library/Fonts/Beirut.ttc',
#  '/Library/Fonts/24516.ttf',
#  '/Library/Fonts/Sathu.ttf',
#  '/Library/Fonts/LFAX.TTF',
#  '/Library/Fonts/SnellRoundhand.ttc',
#  '/Library/Fonts/BOD.TTF',
#  '/Library/Fonts/ArnoPro-Display.otf',
#  '/Library/Fonts/LetterGothicStd-Bold.otf',
#  '/Library/Fonts/BOD_CI_0.TTF',
#  '/System/Library/Fonts/Helvetica.ttc',
#  '/Library/Fonts/NanumGothicLight.ttf',
#  '/Library/Fonts/Songti.ttc',
#  '/System/Library/Fonts/Keyboard.ttf',
#  '/Library/Fonts/Bodoni 72 OS.ttc',
#  '/Library/Fonts/bahnschrift.ttf',
#  '/Library/Fonts/13740.ttf',
#  '/System/Library/Fonts/HelveticaNeue.ttc',
#  '/Library/Fonts/segmdl2.ttf',
#  '/Library/Fonts/10249.ttf',
#  '/Library/Fonts/gadugi.ttf',
#  '/Library/Fonts/70729.TTF',
#  '/Library/Fonts/AdobeNaskh-Medium.otf',
#  '/System/Library/Fonts/GeezaPro.ttc',
#  '/Library/Fonts/ArnoPro-SmbdItalic.otf',
#  '/System/Library/Fonts/PingFang.ttc',
#  '/Library/Fonts/008_0.TTF',
#  '/Library/Fonts/010_0.TTF',
#  '/Library/Fonts/ebrima.ttf',
#  '/System/Library/Fonts/KohinoorTelugu.ttc',
#  '/System/Library/Fonts/Menlo.ttc',
#  '/Library/Fonts/BOD_I_0.TTF',
#  '/Library/Fonts/GARABD.TTF',
#  '/Library/Fonts/LTYPE.TTF',
#  '/Library/Fonts/Baskerville.ttc',
#  '/Library/Fonts/ArnoPro-BoldItalicDisplay.otf',
#  '/Library/Fonts/휴먼나무_0.ttf',
#  '/Library/Fonts/AVD____S.TTF',
#  '/Library/Fonts/PALSCRI.TTF',
#  '/Library/Fonts/msyi.ttf',
#  '/Library/Fonts/ArnoPro-Regular.otf',
#  '/Library/Fonts/63193_0.TTF',
#  '/Library/Fonts/NISC18030.ttf',
#  '/System/Library/Fonts/Apple Braille Pinpoint 8 Dot.ttf',
#  '/Library/Fonts/FRAHV.TTF',
#  '/Library/Fonts/Luminari.ttf',
#  '/Library/Fonts/Charter.ttc',
#  '/Library/Fonts/Candara.ttf',
#  '/Library/Fonts/ArnoPro-Smbd.otf',
#  '/Library/Fonts/14022.ttf',
#  '/Library/Fonts/seguibli.ttf',
#  '/Library/Fonts/consolaz.ttf',
#  '/Library/Fonts/NanumMyeongjo.ttf',
#  '/Library/Fonts/trebucbi.ttf',
#  '/Library/Fonts/Bangla Sangam MN.ttc',
#  '/Library/Fonts/BROADW.TTF',
#  '/Library/Fonts/NanumMyeongjoExtraBold.ttf',
#  '/Library/Fonts/JUMJA.TTF',
#  '/System/Library/Fonts/PingFang.ttc',
#  '/Library/Fonts/94030.ttf',
#  '/Library/Fonts/BOD_I_1.TTF',
#  '/Library/Fonts/Andale Mono.ttf',
#  '/Library/Fonts/SitkaB.ttc',
#  '/Library/Fonts/KoPubDotumLight.ttf',
#  '/Library/Fonts/11059.ttf',
#  '/Library/Fonts/ctsa.ttf',
#  '/Library/Fonts/AmericanTypewriter.ttc',
#  '/System/Library/Fonts/Hiragino Sans GB.ttc',
#  '/System/Library/Fonts/HelveticaNeueDeskInterface.ttc',
#  '/Library/Fonts/NIAGSOL.TTF',
#  '/Library/Fonts/Courier New Bold.ttf',
#  '/System/Library/Fonts/Apple Braille Pinpoint 6 Dot.ttf',
#  '/Library/Fonts/13875.ttf',
#  '/Library/Fonts/Farisi.ttf',
#  '/Library/Fonts/BASKVILL_0.TTF',
#  '/Library/Fonts/Skia.ttf',
#  '/Library/Fonts/Mshtakan.ttc',
#  '/Library/Fonts/ArnoPro-SmbdSmText.otf',
#  '/Library/Fonts/24519.ttf',
#  '/Library/Fonts/angsab.ttf',
#  '/Library/Fonts/NanumSquareExtraBold.ttf',
#  '/Library/Fonts/batang_3.ttc',
#  '/Library/Fonts/ROCKI.TTF',
#  '/Library/Fonts/011_0.TTF',
#  '/System/Library/Fonts/Avenir Next Condensed.ttc',
#  '/Library/Fonts/63193.TTF',
#  '/Library/Fonts/AMGDT.TTF',
#  '/Library/Fonts/HANDotum.ttf',
#  '/Library/Fonts/78936_0.TTF',
#  '/System/Library/Fonts/PingFang.ttc',
#  '/Library/Fonts/LithosPro-Regular.otf',
#  '/Library/Fonts/SuperClarendon.ttc',
#  '/Library/Fonts/ITFDevanagari.ttc',
#  '/Library/Fonts/LCALLIG.TTF',
#  '/Library/Fonts/Damascus.ttc',
#  '/Library/Fonts/HYHWPEQ.TTF',
#  '/System/Library/Fonts/GeezaPro.ttc',
#  '/Library/Fonts/ctsy.ttf',
#  '/Library/Fonts/ANTOC__S_0.TTF',
#  '/Library/Fonts/STIXNonUni.otf',
#  '/Library/Fonts/LSANSD.TTF',
#  '/Library/Fonts/ctrmi.ttf',
#  '/Library/Fonts/msjh.ttc',
#  '/Library/Fonts/BASKVILL_1.TTF',
#  '/System/Library/Fonts/ヒラギノ角ゴシック W0.ttc',
#  '/Library/Fonts/Chalkduster.ttf',
#  '/Library/Fonts/H2MJRE.TTF',
#  '/Library/Fonts/H2MJSM.TTF',
#  '/Library/Fonts/KozMinPro-ExtraLight.otf',
#  '/Library/Fonts/AcadEref_0.ttf',
#  '/Library/Fonts/BOOKD__S.TTF',
#  '/Library/Fonts/92505.ttf',
#  '/System/Library/Fonts/Palatino.ttc',
#  '/Library/Fonts/cambriaz_1.ttf',
#  '/Library/Fonts/cambria.ttc',
#  '/Library/Fonts/batang_2.ttc',
#  '/Library/Fonts/57930.TTF',
#  '/Library/Fonts/LetterGothicStd-BoldSlanted.otf',
#  '/Library/Fonts/Tamil Sangam MN.ttc',
#  '/Library/Fonts/GOUDYSTO.TTF',
#  '/System/Library/Fonts/SFNSTextCondensed-Heavy.otf',
#  '/Library/Fonts/ANTOI__S_0.TTF',
#  '/Library/Fonts/HMFMMUEX.TTC',
#  '/Library/Fonts/Apple Chancery.ttf',
#  '/Library/Fonts/ITCEDSCR.TTF',
#  '/Library/Fonts/simsun.ttc',
#  '/Library/Fonts/MyriadHebrew-Regular.otf',
#  '/Library/Fonts/ENBLBK.TTF',
#  '/Library/Fonts/Malayalam MN.ttc',
#  '/Library/Fonts/ACaslonPro-Regular.otf',
#  '/Library/Fonts/HTOWERT.TTF',
#  '/Library/Fonts/AGaramondPro-Regular.otf',
#  '/Library/Fonts/ArnoPro-SmbdItalicSmText.otf',
#  '/Library/Fonts/BELLI.TTF',
#  '/System/Library/Fonts/Hiragino Sans GB.ttc',
#  '/Library/Fonts/HMKMRHD.TTF',
#  '/Library/Fonts/corbelb_0.ttf',
#  '/Library/Fonts/Arial Italic.ttf',
#  '/System/Library/Fonts/SFNSDisplayCondensed-Medium.otf',
#  '/Library/Fonts/trebuc.ttf',
#  '/Library/Fonts/91546.ttf',
#  '/Library/Fonts/Comic Sans MS.ttf',
#  '/Library/Fonts/CALIST_1.TTF',
#  '/Library/Fonts/Rockwell.ttc',
#  '/Library/Fonts/arialbi_1.ttf',
#  '/Library/Fonts/Iowan Old Style.ttc',
#  '/Library/Fonts/BOOKOSBI_0.TTF',
#  '/Library/Fonts/CENTURY.TTF',
#  '/Library/Fonts/bahnschrift.ttf',
#  '/Library/Fonts/batang.ttc',
#  '/System/Library/Fonts/ArialHB.ttc',
#  '/Library/Fonts/batang_1.ttc',
#  '/Library/Fonts/cambriaz_0.ttf',
#  '/Library/Fonts/bgothm.ttf',
#  '/Library/Fonts/042_0.TTF',
#  '/Library/Fonts/BickhamScriptPro-Semibold_0.otf',
#  '/Library/Fonts/AmericanTypewriter.ttc',
#  '/System/Library/Fonts/STHeiti Light.ttc',
#  '/Library/Fonts/14514.ttf',
#  '/Library/Fonts/Candarai_1.ttf',
#  '/Library/Fonts/DIN Alternate Bold.ttf',
#  '/Library/Fonts/avgr66w_0.ttf',
#  '/System/Library/Fonts/SFCompactDisplay-Bold.otf',
#  '/Library/Fonts/cour_0.ttf',
#  '/Library/Fonts/KoPubDotumBold.ttf',
#  '/Library/Fonts/Bradley Hand Bold.ttf',
#  '/Library/Fonts/SitkaI.ttc',
#  '/Library/Fonts/marlett.ttf',
#  '/System/Library/Fonts/SFNSTextCondensed-Light.otf',
#  '/Library/Fonts/CALIST_0.TTF',
#  '/Library/Fonts/Damascus.ttc',
#  '/Library/Fonts/JUICE___.TTF',
#  '/Library/Fonts/BOOKOSBI_1.TTF',
#  '/Library/Fonts/albr55w.ttf',
#  '/Library/Fonts/arialbi_0.ttf',
#  '/Library/Fonts/AdobeDevanagari-Regular.otf',
#  '/Library/Fonts/HANBatang.ttf',
#  '/System/Library/Fonts/Apple Braille Outline 8 Dot.ttf',
#  '/Library/Fonts/ArnoPro-SmText_0.otf',
#  '/Library/Fonts/batang_0.ttc',
#  '/Library/Fonts/13730.ttf',
#  '/Library/Fonts/13952.ttf',
#  '/Library/Fonts/BOOK___S_0.TTF',
#  '/Library/Fonts/NanumBrush.ttf',
#  '/Library/Fonts/bahnschrift.ttf',
#  '/System/Library/Fonts/AppleSDGothicNeo.ttc',
#  '/Library/Fonts/70214.TTF',
#  '/Library/Fonts/dutch.ttf',
#  '/Library/Fonts/ARESSENCE_0.ttf',
#  '/Library/Fonts/ahronbd.ttf',
#  '/Library/Fonts/14053.ttf',
#  '/Library/Fonts/TCM_____.TTF',
#  '/Library/Fonts/Candarai_0.ttf',
#  '/Library/Fonts/KozGoPr6N-Heavy.otf',
#  '/Library/Fonts/batang.ttc',
#  '/Library/Fonts/ArnoPro-SmbdSubhead_0.otf',
#  '/System/Library/Fonts/SFNSTextItalic.ttf',
#  '/System/Library/Fonts/SFCompactText-MediumItalic.otf',
#  '/System/Library/Fonts/Avenir.ttc',
#  '/Library/Fonts/헤움진명조232_0.ttf',
#  '/Library/Fonts/52162.TTF',
#  '/Library/Fonts/Songti.ttc',
#  '/System/Library/Fonts/Avenir Next.ttc',
#  '/Library/Fonts/bgothm_0.ttf',
#  '/System/Library/Fonts/ヒラギノ角ゴシック W8.ttc',
#  '/Library/Fonts/BOD_PSTC.TTF',
#  '/Library/Fonts/FRADMCN.TTF',
#  '/System/Library/Fonts/SFNSTextItalic.ttf',
#  '/Library/Fonts/11454.ttf',
#  '/Library/Fonts/CENTURY_0.TTF',
#  '/Library/Fonts/Devanagari Sangam MN.ttc',
#  '/Library/Fonts/50416_0.TTF',
#  '/Library/Fonts/AGaramondPro-Italic.otf',
#  '/Library/Fonts/BKANT.TTF',
#  '/Library/Fonts/ArnoPro-ItalicSmText.otf',
#  '/Library/Fonts/Krungthep.ttf',
#  '/Library/Fonts/bahnschrift.ttf',
#  '/Library/Fonts/LeelawUI.ttf',
#  '/Library/Fonts/AdobeHeitiStd-Regular.otf',
#  '/Library/Fonts/cgor66w.ttf',
#  '/Library/Fonts/AMDT_Symbols_0.ttf',
#  '/Library/Fonts/AMDT_Symbols.ttf',
#  '/Library/Fonts/54151_0.TTF',
#  '/Library/Fonts/msyhl.ttc',
#  '/Library/Fonts/LFAXDI.TTF',
#  '/Library/Fonts/TektonPro-BoldObl.otf',
#  '/Library/Fonts/simsun.ttc',
#  '/Library/Fonts/헤움서쪽하늘132.ttf',
#  '/Library/Fonts/12639.ttf',
#  '/Library/Fonts/courbi.ttf',
#  '/Library/Fonts/14054.ttf',
#  '/Library/Fonts/4484.ttf',
#  '/Library/Fonts/DecoTypeNaskh.ttc',
#  '/Library/Fonts/AdobeMyungjoStd-Medium.otf',
#  '/Library/Fonts/ELEPHNTI_0.TTF',
#  '/Library/Fonts/ctem.ttf',
#  '/Library/Fonts/BOOKOSI.TTF',
#  '/System/Library/Fonts/SFCompactText-Bold.otf',
#  '/Library/Fonts/14460.ttf',
#  '/Library/Fonts/Herculanum.ttf',
#  '/Library/Fonts/COPRGTL.TTF',
#  '/Library/Fonts/헤움진명조242.ttf',
#  '/Library/Fonts/FELIXTI.TTF',
#  '/Library/Fonts/mmrtextb.ttf',
#  '/Library/Fonts/CalibriLI_1.ttf',
#  '/Library/Fonts/CENTURY_1.TTF',
#  '/Library/Fonts/Phosphate.ttc',
#  '/Library/Fonts/Silom.ttf',
#  '/Library/Fonts/aldhabi.ttf',
#  '/Library/Fonts/92500.ttf',
#  '/Library/Fonts/BOOKI__S_0.TTF',
#  '/Library/Fonts/헤움스타일152_0.ttf',
#  '/Library/Fonts/SitkaI.ttc',
#  '/Library/Fonts/AdobeArabic-BoldItalic.otf',
#  '/Library/Fonts/Iowan Old Style.ttc',
#  '/Library/Fonts/Oriya Sangam MN.ttc',
#  '/Library/Fonts/Damascus.ttc',
#  '/System/Library/Fonts/HelveticaNeue.ttc',
#  '/Library/Fonts/ARBERKLEY.ttf',
#  '/Library/Fonts/trebucbd.ttf',
#  '/Library/Fonts/STIXSizOneSymBol.otf',
#  '/Library/Fonts/ANTOI__S.TTF',
#  '/Library/Fonts/40240_0.TTF',
#  '/Library/Fonts/ROCCB___.TTF',
#  '/Library/Fonts/constan.ttf',
#  '/Library/Fonts/10267.ttf',
#  '/Library/Fonts/daunpenh.ttf',
#  '/Library/Fonts/ARDELANEY.ttf',
#  '/System/Library/Fonts/KohinoorBangla.ttc',
#  '/Library/Fonts/ctmi.ttf',
#  '/Library/Fonts/CLEB___S.TTF',
#  '/Library/Fonts/AdobeHebrew-Regular.otf',
#  '/Library/Fonts/SitkaI.ttc',
#  '/Library/Fonts/AdobeGothicStd-Bold.otf',
#  '/System/Library/Fonts/SFNSDisplay.ttf',
#  '/Library/Fonts/ebrimabd_0.ttf',
#  '/Library/Fonts/Charter.ttc',
#  '/System/Library/Fonts/AppleSDGothicNeo.ttc',
#  '/Library/Fonts/Kannada Sangam MN.ttc',
#  '/Library/Fonts/InaiMathi-MN.ttc',
#  '/Library/Fonts/BOOKOS.TTF',
#  '/Library/Fonts/corbel_0.ttf',
#  '/Library/Fonts/BRADHITC_1.TTF',
#  '/Library/Fonts/058_0.TTF',
#  '/Library/Fonts/angsa.ttf',
#  '/Library/Fonts/Candaraz.ttf',
#  '/Library/Fonts/HANBatangExtBB.ttf',
#  '/Library/Fonts/constani_0.ttf',
#  '/Library/Fonts/12968.ttf',
#  '/Library/Fonts/헤움서쪽하늘152.ttf',
#  '/Library/Fonts/cambriaz.ttf',
#  '/Library/Fonts/BOOKOSB_1.TTF',
#  '/Library/Fonts/AGaramondPro-BoldItalic_1.otf',
#  '/Library/Fonts/13732.ttf',
#  '/Library/Fonts/AppleMyungjo.ttf',
#  '/Library/Fonts/palai.ttf',
#  '/System/Library/Fonts/SFNSTextCondensed-Bold.otf',
#  '/Library/Fonts/Iowan Old Style.ttc',
#  '/Library/Fonts/browa.ttf',
#  '/Library/Fonts/ArnoPro-Bold_0.otf',
#  '/System/Library/Fonts/ArabicUIText.ttc',
#  '/Library/Fonts/palabi.ttf',
#  '/Library/Fonts/AdobeDevanagari-Italic.otf',
#  '/Library/Fonts/ArnoPro-LightDisplay.otf',
#  '/Library/Fonts/BRADHITC_0.TTF',
#  '/Library/Fonts/Times New Roman.ttf',
#  '/Library/Fonts/51253_0.TTF',
#  '/Library/Fonts/ARCENA.ttf',
#  '/Library/Fonts/BOD_CR_0.TTF',
#  '/Library/Fonts/consolab.ttf',
#  '/Library/Fonts/PTSans.ttc',
#  '/Library/Fonts/46152_0.TTF',
#  '/Library/Fonts/AGaramondPro-Regular_0.otf',
#  '/Library/Fonts/13872.ttf',
#  '/Library/Fonts/CPSBO__S.TTF',
#  '/Library/Fonts/ARIALNBI.TTF',
#  '/Library/Fonts/Microsoft Sans Serif.ttf',
#  '/System/Library/Fonts/Menlo.ttc',
#  '/Library/Fonts/Arial Narrow Bold.ttf',
#  '/Library/Fonts/LBRITEDI.TTF',
#  '/Library/Fonts/Waseem.ttc',
#  '/System/Library/Fonts/HelveticaNeueDeskInterface.ttc',
#  '/Library/Fonts/92504.ttf',
#  '/Library/Fonts/MyriadArabic-BoldIt.otf',
#  '/Library/Fonts/BOOKOSB_0.TTF',
#  '/Library/Fonts/mvboli.ttf',
#  '/System/Library/Fonts/HelveticaNeueDeskInterface.ttc',
#  '/Library/Fonts/AGaramondPro-BoldItalic_0.otf',
#  '/Library/Fonts/tahomabd.ttf',
#  '/Library/Fonts/ARIALNI.TTF',
#  '/Library/Fonts/SitkaZ.ttc',
#  '/Library/Fonts/aparaji.ttf',
#  '/Library/Fonts/015_0.TTF',
#  '/Library/Fonts/Farah.ttc',
#  '/Library/Fonts/corbelb.ttf',
#  '/Library/Fonts/12544.ttf',
#  '/Library/Fonts/ARDESTINE.ttf',
#  '/Library/Fonts/AGaramondPro-Bold.otf',
#  '/System/Library/Fonts/SFNSDisplay-MediumItalic.otf',
#  '/System/Library/Fonts/KohinoorTelugu.ttc',
#  '/System/Library/Fonts/SFNSDisplay.ttf',
#  '/Library/Fonts/AmericanTypewriter.ttc',
#  '/Library/Fonts/041_0.TTF',
#  '/Library/Fonts/059_0.TTF',
#  '/Library/Fonts/Seravek.ttc',
#  '/Library/Fonts/trebucit.ttf',
#  '/Library/Fonts/BOD_CR_1.TTF',
#  '/Library/Fonts/ChalkboardSE.ttc',
#  '/Library/Fonts/BrushScriptStd_0.otf',
#  '/Library/Fonts/AGaramondPro-Regular_1.otf',
#  '/Library/Fonts/ARCHRISTY.ttf',
#  '/Library/Fonts/Cochin.ttc',
#  '/Library/Fonts/ctex.ttf',
#  '/Library/Fonts/14040.ttf',
#  '/Library/Fonts/segoeui.ttf',
#  '/System/Library/Fonts/PingFang.ttc',
#  '/Library/Fonts/AdobeSongStd-Light.otf',
#  '/Library/Fonts/ArnoPro-BoldSmText_0.otf',
#  '/Library/Fonts/BAUHS93.TTF',
#  '/System/Library/Fonts/SFNSTextItalic.ttf',
#  '/Library/Fonts/12640.ttf',
#  '/Library/Fonts/STIXIntUpSmBol.otf',
#  '/Library/Fonts/HANDotumB.ttf',
#  '/Library/Fonts/ARDARLING.ttf',
#  '/Library/Fonts/ARBONNIE.ttf',
#  '/Library/Fonts/SitkaI.ttc',
#  '/Library/Fonts/Times New Roman Bold.ttf',
#  '/System/Library/Fonts/SFCompactText-Semibold.otf',
#  '/Library/Fonts/AGaramondPro-BoldItalic.otf',
#  '/Library/Fonts/ctef.ttf',
#  '/Library/Fonts/휴먼소하.ttf',
#  '/System/Library/Fonts/SFCompactRounded-Black.otf',
#  '/Library/Fonts/GILLUBCD.TTF',
#  '/Library/Fonts/BELLB.TTF',
#  '/Library/Fonts/cambria_0.ttc',
#  '/Library/Fonts/12507.ttf',
#  '/Library/Fonts/24517.ttf',
#  '/Library/Fonts/NewPeninimMT.ttc',
#  '/Library/Fonts/78640_0.TTF',
#  '/Library/Fonts/ArnoPro-BoldSmText.otf',
#  '/Library/Fonts/MyriadPro-CondIt.otf',
#  '/Library/Fonts/ChaparralPro-Italic.otf',
#  '/Library/Fonts/중앙태고딕.ttf',
#  '/Library/Fonts/LATINWD.TTF',
#  '/System/Library/Fonts/ArialHB.ttc',
#  '/Library/Fonts/14507.ttf',
#  '/Library/Fonts/14508.ttf',
#  '/Library/Fonts/14462.ttf',
#  '/Library/Fonts/segoescb.ttf',
#  '/Library/Fonts/BrushScriptStd_1.otf',
#  '/Library/Fonts/dutcheb.ttf',
#  '/System/Library/Fonts/MarkerFelt.ttc',
#  '/Library/Fonts/segoeuisl.ttf',
#  '/System/Library/Fonts/ArialHB.ttc',
#  '/Library/Fonts/CASTELAR.TTF',
#  '/System/Library/Fonts/SFNSDisplay-BlackItalic.otf',
#  '/Library/Fonts/RAVIE.TTF',
#  '/Library/Fonts/4487.ttf',
#  '/Library/Fonts/cgtr65w.ttf',
#  '/Library/Fonts/IMPRISHA.TTF',
#  '/System/Library/Fonts/SFCompactDisplay-Semibold.otf',
#  '/Library/Fonts/HANBatangB.ttf',
#  '/System/Library/Fonts/SFCompactRounded-Thin.otf',
#  '/Library/Fonts/consola_0.ttf',
#  '/Library/Fonts/TCMI____.TTF',
#  '/Library/Fonts/cambria_1.ttc',
#  '/System/Library/Fonts/ヒラギノ角ゴシック W7.ttc',
#  '/Library/Fonts/Oriya MN.ttc',
#  '/Library/Fonts/batang_3.ttc',
#  '/System/Library/Fonts/Optima.ttc',
#  '/Library/Fonts/Arial Narrow.ttf',
#  '/Library/Fonts/coronet.ttf',
#  '/Library/Fonts/RosewoodStd-Regular.otf',
#  '/System/Library/Fonts/Optima.ttc',
#  '/Library/Fonts/Baskerville.ttc',
#  '/Library/Fonts/YuGothB.ttc',
#  '/Library/Fonts/Myanmar Sangam MN.ttc',
#  '/Library/Fonts/BRUSHSCI_0.TTF',
#  '/Library/Fonts/Georgia Italic.ttf',
#  '/Library/Fonts/BOD_R.TTF',
#  '/Library/Fonts/H2MKPB.TTF',
#  '/Library/Fonts/CURLZ__.TTF',
#  '/Library/Fonts/KozGoPr6N-Light.otf',
#  '/Library/Fonts/57961.TTF',
#  '/Library/Fonts/ChaparralPro-Regular.otf',
#  '/Library/Fonts/Savoye LET.ttc',
#  '/Library/Fonts/symbol.ttf',
#  '/Library/Fonts/ENBASKVL.TTF',
#  '/Library/Fonts/SitkaZ.ttc',
#  '/Library/Fonts/calibriz_1.ttf',
#  '/System/Library/Fonts/PingFang.ttc',
#  '/Library/Fonts/AmericanTypewriter.ttc',
#  '/Library/Fonts/Lao MN.ttc',
#  '/System/Library/Fonts/Avenir Next Condensed.ttc',
#  '/System/Library/Fonts/Helvetica.ttc',
#  '/System/Library/Fonts/SFNSTextCondensed-Regular.otf',
#  '/Library/Fonts/cordiai.ttf',
#  '/System/Library/Fonts/Avenir Next Condensed.ttc',
#  '/Library/Fonts/Verdana Bold.ttf',
#  '/System/Library/Fonts/LucidaGrande.ttc',
#  '/Library/Fonts/APPCH__S_0.TTF',
#  '/Library/Fonts/batang_2.ttc',
#  '/Library/Fonts/13950.ttf',
#  '/Library/Fonts/ebrima_0.ttf',
#  '/Library/Fonts/STIXVar.otf',
#  '/Library/Fonts/ITFDevanagari.ttc',
#  '/Library/Fonts/Muna.ttc',
#  '/Library/Fonts/ctmib.ttf',
#  '/Library/Fonts/BRUSHSCI_1.TTF',
#  '/Library/Fonts/BOD_1.TTF',
#  '/Library/Fonts/BickhamScriptPro-Bold.otf',
#  '/Library/Fonts/HMKMAMI.TTF',
#  '/Library/Fonts/NuevaStd-BoldCond.otf',
#  '/System/Library/Fonts/ArabicUIDisplay.ttc',
#  '/Library/Fonts/34456.ttf',
#  '/Library/Fonts/Rockwell.ttc',
#  '/System/Library/Fonts/SFCompactDisplay-Thin.otf',
#  '/Library/Fonts/ArnoPro-ItalicCaption.otf',
#  '/Library/Fonts/NuevaStd-Italic.otf',
#  '/Library/Fonts/couri.ttf',
#  '/Library/Fonts/FRADMIT.TTF',
#  '/Library/Fonts/GILB____.TTF',
#  '/Library/Fonts/AlBayan.ttc',
#  '/Library/Fonts/ITCBLKAD.TTF',
#  '/Library/Fonts/MinionPro-MediumIt.otf',
#  '/Library/Fonts/047_0.TTF',
#  '/Library/Fonts/taileb.ttf',
#  '/Library/Fonts/헤움진명조262_0.ttf',
#  '/Library/Fonts/BOOKI__S.TTF',
#  '/Library/Fonts/Beirut.ttc',
#  '/Library/Fonts/BellGothicStd-Bold.otf',
#  '/Library/Fonts/batang_1.ttc',
#  '/Library/Fonts/12582.ttf',
#  '/Library/Fonts/ARCARTER.ttf',
#  '/Library/Fonts/BRUSHSCI.TTF',
#  '/Library/Fonts/Skia.ttf',
#  '/System/Library/Fonts/SFCompactDisplay-Regular.otf',
#  '/Library/Fonts/H2SA1M.TTF',
#  '/Library/Fonts/STIXGeneral.otf',
#  '/Library/Fonts/ctmtex.ttf',
#  '/System/Library/Fonts/KohinoorBangla.ttc',
#  '/Library/Fonts/Hoefler Text.ttc',
#  '/Library/Fonts/MN.TTF',
#  '/Library/Fonts/PoplarStd.otf',
#  '/Library/Fonts/34458.ttf',
#  '/Library/Fonts/arialbd_1.ttf',
#  '/Library/Fonts/SitkaB.ttc',
#  '/Library/Fonts/14513.ttf',
#  '/Library/Fonts/a피오피버블_0.ttf',
#  '/Library/Fonts/AdobeFanHeitiStd-Bold.otf',
#  '/Library/Fonts/NanumBarunpenRegular.ttf',
#  '/Library/Fonts/STIXNonUniBolIta.otf',
#  '/Library/Fonts/Telugu Sangam MN.ttc',
#  '/Library/Fonts/MyriadPro-BoldCond.otf',
#  '/Library/Fonts/BOD_BI_0.TTF',
#  '/Library/Fonts/KozGoPro-Bold.otf',
#  '/Library/Fonts/12704.ttf',
#  '/Library/Fonts/cordiaub.ttf',
#  '/Library/Fonts/dokchamp.ttf',
#  '/Library/Fonts/GILI____.TTF',
#  '/Library/Fonts/calibril_0.ttf',
#  '/Library/Fonts/94040.ttf',
#  '/Library/Fonts/NIAGENG.TTF',
#  '/Library/Fonts/중앙신문명조.ttf',
#  '/Library/Fonts/92510.ttf',
#  '/Library/Fonts/timesbd.ttf',
#  '/Library/Fonts/batang_0.ttc',
#  '/Library/Fonts/AVO____S.TTF',
#  '/Library/Fonts/STIXSizTwoSymBol.otf',
#  '/Library/Fonts/ArnoPro-SmbdSubhead.otf',
#  '/Library/Fonts/BODP___S_0.TTF',
#  '/Library/Fonts/ARBERKLEY_0.ttf',
#  '/Library/Fonts/calibriz.ttf',
#  '/Library/Fonts/93777.ttf',
#  '/Library/Fonts/ahn_l_2.ttf',
#  '/Library/Fonts/91118.ttf',
#  '/Library/Fonts/ITFDevanagari.ttc',
#  '/Library/Fonts/arialbd_0.ttf',
#  '/Library/Fonts/cgtr45w.ttf',
#  '/System/Library/Fonts/HelveticaNeueDeskInterface.ttc',
#  '/Library/Fonts/STIXSizThreeSymBol.otf',
#  '/Library/Fonts/STIXVarBol.otf',
#  '/Library/Fonts/BRLNSB.TTF',
#  '/Library/Fonts/Bodoni 72 Smallcaps Book.ttf',
#  '/System/Library/Fonts/SFCompactText-SemiboldItalic.otf',
#  '/Library/Fonts/LHANDW.TTF',
#  '/Library/Fonts/휴먼신중간샘.ttf',
#  '/Library/Fonts/BOD_BI_1.TTF',
#  '/Library/Fonts/Iowan Old Style.ttc',
#  '/Library/Fonts/gadugib.ttf',
#  '/Library/Fonts/92507.ttf',
#  '/Library/Fonts/Bodoni 72.ttc',
#  '/Library/Fonts/courbd_0.ttf',
#  '/Library/Fonts/ArnoPro-BoldItalicDisplay_0.otf',
#  '/Library/Fonts/STIXIntUpDBol.otf',
#  '/Library/Fonts/andlso.ttf',
#  '/System/Library/Fonts/SFNSDisplayCondensed-Black.otf',
#  '/Library/Fonts/AGENCYR_0.TTF',
#  '/Library/Fonts/AIGDT_0.TTF',
#  '/Library/Fonts/ArnoPro-BoldDisplay_0.otf',
#  '/Library/Fonts/SukhumvitSet.ttc',
#  '/System/Library/Fonts/Kohinoor.ttc',
#  '/Library/Fonts/dutchi.ttf',
#  '/System/Library/Fonts/HelveticaNeue.ttc',
#  '/System/Library/Fonts/HelveticaNeue.ttc',
#  '/Library/Fonts/AdobeMingStd-Light.otf',
#  '/Library/Fonts/BellGothicStd-Black_0.otf',
#  '/Library/Fonts/taile.ttf',
#  '/Library/Fonts/Damascus.ttc',
#  '/Library/Fonts/msjh.ttc',
#  '/Library/Fonts/12585.ttf',
#  '/Library/Fonts/browaub.ttf',
#  '/Library/Fonts/batang.ttc',
#  '/Library/Fonts/068_0.TTF',
#  '/Library/Fonts/070_0.TTF',
#  '/Library/Fonts/CENSCBK.TTF',
#  '/Library/Fonts/BOD_B.TTF',
#  '/Library/Fonts/cordiaz.ttf',
#  '/Library/Fonts/NanumMyeongjoBold.ttf',
#  '/Library/Fonts/CALIFB.TTF',
#  '/Library/Fonts/STIXIntDBol.otf',
#  '/Library/Fonts/ahn_l_1.ttf',
#  '/Library/Fonts/ArnoPro-SmbdSmText_0.otf',
#  '/Library/Fonts/PERTILI.TTF',
#  '/Library/Fonts/BOD_CBI_1.TTF',
#  '/System/Library/Fonts/ヒラギノ明朝 ProN.ttc',
#  '/Library/Fonts/MAIAN.TTF',
#  '/Library/Fonts/ITCKRIST.TTF',
#  '/Library/Fonts/ChaparralPro-LightIt.otf',
#  '/Library/Fonts/NewPeninimMT.ttc',
#  '/System/Library/Fonts/AppleSDGothicNeo.ttc',
#  '/Library/Fonts/BOOKD__S_0.TTF',
#  '/Library/Fonts/13777.ttf',
#  '/Library/Fonts/corbel.ttf',
#  '/Library/Fonts/Georgia Bold.ttf',
#  '/Library/Fonts/BlackoakStd_0.otf',
#  '/Library/Fonts/CALIST.TTF',
#  '/Library/Fonts/94023.ttf',
#  '/System/Library/Fonts/SFCompactDisplay-Heavy.otf',
#  '/Library/Fonts/AGENCYR_1.TTF',
#  '/System/Library/Fonts/ヒラギノ角ゴシック W6.ttc',
#  '/Library/Fonts/bahnschrift.ttf',
#  '/Library/Fonts/휴먼견출새내기.ttf',
#  '/Library/Fonts/EuphemiaCAS.ttc',
#  '/System/Library/Fonts/ArabicUIDisplay.ttc',
#  '/Library/Fonts/Hoefler Text Ornaments.ttf',
#  '/Library/Fonts/MinionPro-SemiboldIt.otf',
#  '/System/Library/Fonts/PingFang.ttc',
#  '/Library/Fonts/TCBI____.TTF',
#  '/System/Library/Fonts/Noteworthy.ttc',
#  '/System/Library/Fonts/PingFang.ttc',
#  '/Library/Fonts/11118.ttf',
#  '/Library/Fonts/12675.ttf',
#  '/Library/Fonts/bokr35w.ttf',
#  '/Library/Fonts/msgothic.ttc',
#  '/Library/Fonts/avgr45w_0.ttf',
#  '/Library/Fonts/a피오피버블.ttf',
#  '/Library/Fonts/bahnschrift.ttf',
#  '/Library/Fonts/BODPC__S_0.TTF',
#  '/Library/Fonts/BickhamScriptPro-Regular.otf',
#  '/Library/Fonts/ahn_m_2.ttf',
#  '/Library/Fonts/verdanab.ttf',
#  '/Library/Fonts/휴먼나무.ttf',
#  '/Library/Fonts/Myanmar MN.ttc',
#  '/Library/Fonts/ahn_l_0.ttf',
#  '/Library/Fonts/FRABKIT.TTF',
#  '/Library/Fonts/AdobeKaitiStd-Regular.otf',
#  '/Library/Fonts/BOD_CBI_0.TTF',
#  '/Library/Fonts/14503.ttf',
#  '/Library/Fonts/Muna.ttc',
#  '/Library/Fonts/mingliub.ttc',
#  '/Library/Fonts/ARIALNI_0.TTF',
#  '/Library/Fonts/ArnoPro-ItalicDisplay.otf',
#  '/Library/Fonts/MISTRAL.TTF',
#  '/Library/Fonts/BlackoakStd_1.otf',
#  '/Library/Fonts/SuperClarendon.ttc',
#  '/System/Library/Fonts/AppleSDGothicNeo.ttc',
#  '/Library/Fonts/ACaslonPro-Regular_0.otf',
#  '/Library/Fonts/ROCC____.TTF',
#  '/System/Library/Fonts/Avenir.ttc',
#  '/Library/Fonts/Skia.ttf',
#  '/Library/Fonts/ArnoPro-BoldItalicSmText.otf',
#  '/System/Library/Fonts/Avenir Next.ttc',
#  '/Library/Fonts/BOD_BLAI.TTF',
#  '/Library/Fonts/simsunb.ttf',
#  '/Library/Fonts/94021.ttf',
#  '/Library/Fonts/14051.ttf',
#  '/System/Library/Fonts/AppleSDGothicNeo.ttc',
#  '/Library/Fonts/PTMono.ttc',
#  '/Library/Fonts/phagspa.ttf',
#  '/Library/Fonts/BellGothicStd-Black.otf',
#  '/Library/Fonts/avgr65w_0.ttf',
#  '/Library/Fonts/GOUDOSI.TTF',
#  '/Library/Fonts/069_0.TTF',
#  '/Library/Fonts/12625.ttf',
#  '/Library/Fonts/verdanaz.ttf',
#  '/Library/Fonts/Waseem.ttc',
#  '/Library/Fonts/SitkaZ.ttc',
#  '/System/Library/Fonts/HelveticaNeue.ttc',
#  '/System/Library/Fonts/STHeiti Medium.ttc',
#  '/Library/Fonts/Sinhala MN.ttc',
#  '/Library/Fonts/courbd.ttf',
#  '/Library/Fonts/ArnoPro-Italic.otf',
#  '/Library/Fonts/ArnoPro-SmbdItalicSubhead.otf',
#  '/Library/Fonts/ArnoPro-SmbdItalicSubhead_0.otf',
#  '/Library/Fonts/ONYX.TTF',
#  '/Library/Fonts/12581.ttf',
#  '/System/Library/Fonts/SFNSText.ttf',
#  '/Library/Fonts/constanz.ttf',
#  '/Library/Fonts/CHILLER.TTF',
#  '/Library/Fonts/ARIALNI_1.TTF',
#  '/Library/Fonts/AdobeHebrew-Bold.otf',
#  '/Library/Fonts/Songti.ttc',
#  '/Library/Fonts/BRLNSDB_0.TTF',
#  '/Library/Fonts/malgunsl.ttf',
#  '/Library/Fonts/BELLB_0.TTF',
#  '/Library/Fonts/ACaslonPro-Regular_1.otf',
#  '/Library/Fonts/ERASMD.TTF',
#  '/Library/Fonts/NanumSquareLight.ttf',
#  '/Library/Fonts/SukhumvitSet.ttc',
#  '/Library/Fonts/AMGDT_0.TTF',
#  '/Library/Fonts/Georgia Bold Italic.ttf',
#  '/Library/Fonts/ALBMTL_S_0.TTF',
#  '/Library/Fonts/ArnoPro-Regular_0.otf',
#  '/Library/Fonts/ArnoPro-LightItalicDisplay_0.otf',
#  '/Library/Fonts/13874.ttf',
#  '/Library/Fonts/msyhbd.ttc',
#  '/Library/Fonts/13502.ttf',
#  '/Library/Fonts/Gabriola.ttf',
#  '/Library/Fonts/MH.TTF',
#  '/Library/Fonts/NuevaStd-CondItalic.otf',
#  '/Library/Fonts/YuGothR.ttc',
#  '/Library/Fonts/Daum_SemiBold.ttf',
#  '/System/Library/Fonts/ヒラギノ角ゴシック W8.ttc',
#  '/Library/Fonts/cambriab.ttf',
#  '/Library/Fonts/COPRGTL_0.TTF',
#  '/Library/Fonts/MyriadHebrew-BoldIt.otf',
#  '/Library/Fonts/AdobeArabic-Bold.otf',
#  '/Library/Fonts/MB.TTF',
#  '/Library/Fonts/l_10646.ttf',
#  '/Library/Fonts/ArnoPro-ItalicDisplay_0.otf',
#  '/Library/Fonts/12510.ttf',
#  '/Library/Fonts/STIXSizFourSymReg.otf',
#  '/Library/Fonts/59250_0.TTF',
#  '/Library/Fonts/Marion.ttc',
#  '/Library/Fonts/ArnoPro-Subhead.otf',
#  '/Library/Fonts/중앙중명조.ttf',
#  '/System/Library/Fonts/SFCompactDisplay-Light.otf',
#  '/Library/Fonts/HARLOWSI.TTF',
#  '/Library/Fonts/EuphemiaCAS.ttc',
#  '/Library/Fonts/SukhumvitSet.ttc',
#  '/Library/Fonts/dutchbi.ttf',
#  '/Library/Fonts/VLADIMIR.TTF',
#  '/Library/Fonts/ahn_m_0.ttf',
#  '/Library/Fonts/GILC____.TTF',
#  '/System/Library/Fonts/SFNSDisplay.ttf',
#  '/Library/Fonts/Bodoni 72.ttc',
#  '/Library/Fonts/KozMinPr6N-ExtraLight.otf',
#  '/Library/Fonts/Tamil Sangam MN.ttc',
#  '/Library/Fonts/ELEPHNT_0.TTF',
#  '/Library/Fonts/14505.ttf',
#  '/Library/Fonts/BRLNSDB_1.TTF',
#  '/Library/Fonts/BELLB_1.TTF',
#  '/Library/Fonts/FORTE.TTF',
#  '/Library/Fonts/14530.ttf',
#  '/Library/Fonts/Oriya MN.ttc',
#  '/System/Library/Fonts/Avenir Next Condensed.ttc',
#  '/System/Library/Fonts/Helvetica.ttc',
#  '/Library/Fonts/webdings.ttf',
#  '/Library/Fonts/91119.ttf',
#  '/Library/Fonts/022_0.TTF',
#  '/Library/Fonts/LFAXD.TTF',
#  '/Library/Fonts/bahnschrift.ttf',
#  '/System/Library/Fonts/SFCompactText-HeavyItalic.otf',
#  '/Library/Fonts/calibrili.ttf',
#  '/Library/Fonts/verdana.ttf',
#  '/Library/Fonts/10370.ttf',
#  '/Library/Fonts/13871.ttf',
#  '/Library/Fonts/davidbd.ttf',
#  '/Library/Fonts/ChalkboardSE.ttc',
#  '/Library/Fonts/CALISTI_1.TTF',
#  '/Library/Fonts/ACaslonPro-Italic.otf',
#  '/Library/Fonts/ahn_m_1.ttf',
#  '/System/Library/Fonts/SFCompactRounded-Ultralight.otf',
#  '/Library/Fonts/ACaslonPro-Bold_1.otf',
#  '/Library/Fonts/corbelz_0.ttf',
#  '/Library/Fonts/seguisb.ttf',
#  '/Library/Fonts/angsaz.ttf',
#  '/Library/Fonts/holomdl2.ttf',
#  '/Library/Fonts/Damascus.ttc',
#  '/System/Library/Fonts/Palatino.ttc',
#  '/System/Library/Fonts/Avenir Next Condensed.ttc',
#  '/Library/Fonts/STIXGeneralItalic.otf',
#  '/Library/Fonts/11546.ttf',
#  '/Library/Fonts/PERB____.TTF',
#  '/Library/Fonts/DecoTypeNaskh.ttc',
#  '/System/Library/Fonts/SFCompactRounded-Regular.otf',
#  '/Library/Fonts/MT.TTF',
#  '/Library/Fonts/POORICH.TTF',
#  '/Library/Fonts/arialbi.ttf',
#  '/Library/Fonts/Trebuchet MS Bold.ttf',
#  '/Library/Fonts/Al Tarikh.ttc',
#  '/System/Library/Fonts/SFNSDisplayCondensed-Ultralight.otf',
#  '/System/Library/Fonts/Helvetica.ttc',
#  '/System/Library/Fonts/ArabicUIText.ttc',
#  '/Library/Fonts/BRADHITC.TTF',
#  '/Library/Fonts/CALISTI_0.TTF',
#  '/Library/Fonts/STIXSizTwoSymReg.otf',
#  '/Library/Fonts/SukhumvitSet.ttc',
#  '/System/Library/Fonts/ZapfDingbats.ttf',
#  '/Library/Fonts/CALIFI_0.TTF',
#  '/Library/Fonts/Corsiva.ttc',
#  '/Library/Fonts/MyriadArabic-Regular.otf',
#  '/Library/Fonts/SuperClarendon.ttc',
#  '/Library/Fonts/seguili.ttf',
#  '/Library/Fonts/13779.ttf',
#  '/Library/Fonts/ACaslonPro-Bold_0.otf',
#  '/Library/Fonts/PERBI___.TTF',
#  '/Library/Fonts/SitkaB.ttc',
#  '/System/Library/Fonts/HelveticaNeue.ttc',
#  '/Library/Fonts/PTSerif.ttc',
#  '/Library/Fonts/MyriadArabic-Bold.otf',
#  '/Library/Fonts/57930_0.TTF',
#  '/Library/Fonts/헤움진명조252_0.ttf',
#  '/Library/Fonts/SHOWG.TTF',
#  '/System/Library/Fonts/PingFang.ttc',
#  '/System/Library/Fonts/PingFang.ttc',
#  '/Library/Fonts/MinionPro-BoldIt.otf',
#  '/Library/Fonts/LTYPEO.TTF',
#  '/Library/Fonts/browai.ttf',
#  '/System/Library/Fonts/SFNSDisplay.ttf',
#  '/Library/Fonts/BRITANIC.TTF',
#  '/Library/Fonts/AGaramondPro-Bold_1.otf',
#  '/Library/Fonts/023_0.TTF',
#  '/Library/Fonts/OUTLOOK.TTF',
#  '/Library/Fonts/Bodoni 72.ttc',
#  '/System/Library/Fonts/SFCompactRounded-Semibold.otf',
#  '/Library/Fonts/Gujarati Sangam MN.ttc',
#  '/Library/Fonts/13741.ttf',
#  '/Library/Fonts/COOPBL.TTF',
#  '/Library/Fonts/a피오피네모_0.ttf',
#  '/Library/Fonts/Myanmar MN.ttc',
#  '/Library/Fonts/COLONNA.TTF',
#  '/Library/Fonts/CALIFI_1.TTF',
#  '/Library/Fonts/CharlemagneStd-Bold.otf',
#  '/Library/Fonts/ITFDevanagari.ttc',
#  '/Library/Fonts/ctembi.ttf',
#  '/Library/Fonts/GillSans.ttc',
#  '/Library/Fonts/ebrimabd.ttf',
#  '/Library/Fonts/ACaslonPro-BoldItalic_0.otf',
#  '/Library/Fonts/ArnoPro-Subhead_0.otf',
#  '/Library/Fonts/12506.ttf',
#  '/Library/Fonts/4483.ttf',
#  '/Library/Fonts/KozMinPro-Regular.otf',
#  '/Library/Fonts/bahnschrift.ttf',
#  '/Library/Fonts/SnellRoundhand.ttc',
#  '/Library/Fonts/Times New Roman Bold Italic.ttf',
#  '/Library/Fonts/COPRGTB_0.TTF',
#  '/Library/Fonts/tahoma.ttf',
#  '/Library/Fonts/cityb.ttf',
#  '/Library/Fonts/MyriadPro-BoldCondIt.otf',
#  '/Library/Fonts/Telugu MN.ttc',
#  '/System/Library/Fonts/PingFang.ttc',
#  '/Library/Fonts/AGaramondPro-Bold_0.otf',
#  '/System/Library/Fonts/SFNSDisplayCondensed-Bold.otf',
#  '/System/Library/Fonts/Avenir.ttc',
#  '/Library/Fonts/Al Tarikh.ttc',
#  '/Library/Fonts/MK.TTF',
#  '/Library/Fonts/calibri_0.ttf',
#  '/Library/Fonts/BELL_0.TTF',
#  '/Library/Fonts/Papyrus.ttc',
#  '/System/Library/Fonts/PingFang.ttc',
#  '/System/Library/Fonts/SFNSDisplay.ttf',
#  '/Library/Fonts/Baskerville.ttc',
#  '/Library/Fonts/PERI____.TTF',
#  '/Library/Fonts/93778.ttf',
#  '/System/Library/Fonts/PingFang.ttc',
#  '/Library/Fonts/ACaslonPro-BoldItalic_1.otf',
#  '/Library/Fonts/COOPBL_0.TTF',
#  '/Library/Fonts/93779.ttf',
#  '/Library/Fonts/70729_0.TTF',
#  '/Library/Fonts/STIXIntUpDReg.otf',
#  '/Library/Fonts/92511.ttf',
#  '/Library/Fonts/Charter.ttc',
#  '/Library/Fonts/NirmalaS.ttf',
#  '/Library/Fonts/ARDESTINE_0.ttf',
#  '/Library/Fonts/angsauz.ttf',
#  '/Library/Fonts/a피오피동글OL_0.ttf',
#  '/Library/Fonts/074_0.TTF',
#  '/Library/Fonts/Devanagari Sangam MN.ttc',
#  '/Library/Fonts/13778.ttf',
#  '/System/Library/Fonts/HelveticaNeue.ttc',
#  '/Library/Fonts/ChaparralPro-Bold_0.otf',
#  '/Library/Fonts/Sitka.ttc',
#  '/Library/Fonts/BELL_1.TTF',
#  '/Library/Fonts/Mshtakan.ttc',
#  '/Library/Fonts/Courier New Bold Italic.ttf',
#  '/Library/Fonts/PTSerif.ttc',
#  '/Library/Fonts/13731.ttf',
#  '/Library/Fonts/Skia.ttf',
#  '/Library/Fonts/ArnoPro-SmbdCaption.otf',
#  '/System/Library/Fonts/ArabicUIText.ttc',
#  '/Library/Fonts/13780.ttf',
#  '/System/Library/Fonts/AppleSDGothicNeo.ttc',
#  '/Library/Fonts/Songti.ttc',
#  '/Library/Fonts/NuevaStd-Bold.otf',
#  '/Library/Fonts/bgothl.ttf',
#  '/Library/Fonts/cordiab.ttf',
#  '/Library/Fonts/14525.ttf',
#  '/Library/Fonts/BSSYM7.TTF',
#  '/Library/Fonts/ALXB__UB_0.TTF',
#  '/System/Library/Fonts/SFNSDisplay.ttf',
#  '/Library/Fonts/COPRGTB.TTF',
#  '/Library/Fonts/ACaslonPro-SemiboldItalic.otf',
#  '/Library/Fonts/HMFMMUEX.TTC',
#  '/Library/Fonts/Al Nile.ttc',
#  '/Library/Fonts/ANTOB__S.TTF',
#  '/Library/Fonts/msyhbd.ttc',
#  '/Library/Fonts/65659.TTF',
#  '/Library/Fonts/MATURASC.TTF',
#  '/Library/Fonts/H2GSRB.TTF',
#  '/Library/Fonts/BirchStd_0.otf',
#  '/Library/Fonts/SignPainter.ttc',
#  '/Library/Fonts/Damascus.ttc',
#  '/Library/Fonts/Futura.ttc',
#  '/System/Library/Fonts/SFNSTextCondensed-Semibold.otf',
#  '/Library/Fonts/consolai_0.ttf',
#  '/Library/Fonts/corbeli_0.ttf',
#  '/Library/Fonts/ctrmb.ttf',
#  ...]

# %%
# 혹은 폰트 경로를 직접 전달해줘도 동작합니다.
# 다만 사용가능한 폰트 목록과 확장자명 확인이 필요합니다.
font_location = '/Library/Fonts/Arial Unicode.ttf' # for 맥
# font_location = 'C:/Windows/Fonts/NanumGothic.ttf' # for windows
font_name = fm.FontProperties(fname=font_location).get_name()
plt.rc('font', family=font_name)

# %% [markdown]
# ### 기본적인 line plot 그리기
#     line plot은 시간 혹은 순서에 따라 데이터가 어떻게 변화하는지를 보기위해 주로 사용한다.

# %%
# numpy array로 시각화 데이터 생성
# arange, linspace
x = np.arange(-10, 10)
y = x ** 2

x1 = np.linspace(-10, 10, 200)
y1 = x1 ** 3

# %%
# line plot - plt.plot(x축 데이터, y축 데이터)
# plt.show() plt 함수로 정의 한 그래프 설정을 그래프화 시키는 명령어
plt.plot(x, y) # 그리고
plt.show() # 보이기

# %% [markdown]
# #### 스타일 지정
#     plot명령어는 보는 사람이 그래프를 조금 더 보기 편하게 하기 위한 다양한 스타일을 지원한다.
#     plot(데이터, '문자열인수')

# %%
# line plot 스타일 지정
# 스타일 문자열은 색, 마커, 선 종류 순으로 지정하며 만약 이중 일부가 생략되면 디폴트 값이 적용됩니다.
plt.plot(x, y, 'r:') # 그리고
plt.show() # 보이기

# %% [markdown]
# #### 자주 사용하는 선스타일 색상
#     자주 사용되는 색깔은 한글자 약자를 사용할 수 있으며 약자는 아래 표에 정리하였습니다.
# | 문자열 | 약자 |
# |-|-|
# | blue | `b` |
# | green | `g` |
# | red | `r` |
# | cyan | `c` |
# | magenta | `m` |
# | yellow | `y` |
# | black | `k` |
# | white | `w` |

# %% [markdown]
# #### 마커
#     데이터의 위치를 표기하는 기호를 마커라고 합니다.
#     사용가능한 마커의 종류를 아래 정리 해두었습니다.
# | 마커 문자열 | 의미 | 마커 문자열 | 의미 |
# |-|-|-|-|
# | `.` | point marker  | `1` | tri_down marker |
# | `,` | pixel marker | `2` | tri_up marker |
# | `o` | circle marker | `3` | tri_left marker |
# | `v` | triangle_down marker | `4` | tri_right marker |
# | `^` | triangle_up marker | `s` | square marker |
# | `<` | triangle_left marker | `p` | pentagon marker |
# | `>` | triangle_right marker | `*` | star marker |
# | `h` | hexagon1 marker | `x` | x marker |
# | `H` | hexagon2 marker | `D` | diamond marker |
# | `+` | plus marker | `d` | thin_diamond marker |

# %% [markdown]
# #### 선 스타일
#     선 스타일에는 실선(solid), 대시선(dashed), 점선(dotted), 대시-점선(dash-dit)을 사용가능합니다.
#
# | 선 스타일 문자열 | 의미 |
# |-|-|
# | `-` |  solid line style
# | `--` |  dashed line style
# | `-.` |  dash-dot line style
# | `:` |  dotted line style

# %% [markdown]
# #### 그래프에 옵션 추가하기
# > 기본 line plot을 조금 더 색다르게 꾸밀 수 있는 스타일을 지금까지 알아봤다면
# 지금부터는 plt 의 다른 함수를 사용하여 보는 사람의 이해를 도울 수 있는 여러 기능들을 알아보겠습니다.
#
# >> `figure` : 그래프가 그려지는 캔버스 설정
# `title` : 그래프 제목
# `xlabel`, `ylabel` : 축 설명
# `legend` : 범례이름
# `xlim`, `ylim` : 축 범위
# `xticks`, `yticks` : 축 구간 내 필요한 구간만 추리기

# %%
# 그래프 크기조정
plt.figure(figsize=(8, 4))
plt.plot(x, y, 'r:') # 그리고
plt.show() # 보이기

# %%
# 그래프 타이틀 지정
plt.figure(figsize=(8, 4))
plt.title('$X^2$')
plt.plot(x, y, 'r:') # 그리고
plt.show() # 보이기

# %%
# 축 타이틀 지정 (축 설명)
plt.figure(figsize=(8, 4))
plt.title('$X^2$')
plt.ylabel('$x^2$')
plt.xlabel('$x$')
plt.plot(x, y, 'r:') # 그리고
plt.show() # 보이기

# %%
# 범례지정
plt.figure(figsize=(8, 4))
plt.title('$X^2$ and $X^3$')
plt.ylabel('$x^2$ and $x^3$')
plt.xlabel('$x$')
plt.plot(x, y, 'r:', label='$x^2$') # 그리고
plt.plot(x1, y1, label='$x^3$')
plt.legend() # 범례 보이기
plt.show() # 보이기

# %%
# 축 범위 설정
plt.figure(figsize=(8, 4))
plt.title('$X^2$ and $X^3$')
plt.ylabel('$x^2$ and $x^3$')
plt.xlabel('$x$')
plt.plot(x, y, 'r:', label='$x^2$') # 그리고
plt.plot(x1, y1, label='$x^3$')
plt.plot(x1, np.sin(x1), label='$x^3$')
plt.xlim(-10, 10)
plt.ylim(-1, 1)
plt.legend() # 범례 보이기
plt.show() # 보이기

# %%
# 축 구간 지정
plt.figure(figsize=(8, 4))
plt.title('$X^2$ and $X^3$')
plt.ylabel('$x^2$ and $x^3$')
plt.xlabel('$x$')
plt.plot(x, y, 'r:', label='$x^2$') # 그리고
plt.plot(x1, y1, label='$x^3$')
# plt.plot(x1, np.sin(x1), label='$x^3$')
# plt.xlim(-10, 10)
# plt.ylim(-1, 1)
plt.xticks([-10, 0 , 10])
plt.yticks([-1000, -500 , 0 , 500, 1000])
plt.legend() # 범례 보이기
plt.show() # 보이기

# %% [markdown]
# #### y축에 x의 세제곱 그래프를 그려봅니다. 라인은 노랑색, 선은 실선, 마커는 없어요. 제목은 '$X^3$', plot label=''$x^3$' 범례지정까지 해봅니다.

# %%
plt.figure(figsize=(8, 4))
plt.title('$X^3$')
plt.ylabel('$x^3$')
plt.xlabel('$x$')
plt.plot(x1, y1, 'y-', label='$x^3$')
# plt.plot(x1, np.sin(x1), label='$x^3$')
# plt.xlim(-10, 10)
# plt.ylim(-1, 1)
# plt.xticks([-10, 0 , 10])
# plt.yticks([-1000, -500 , 0 , 500, 1000])
plt.legend() # 범례 보이기
plt.show() # 보이기

# %%
# 여러 그래프 한꺼번에 그리기
plt.figure(figsize=(10, 7))
plt.title('$x^2$ and $x^3$')
x = np.linspace(-10, 10, 300)
plt.plot(x, x*x, label='$x^2$')
plt.plot(x, x*x*x, 'r--', label='$x^3$')
plt.plot(x, np.sin(x), 'g:', label='$sin(x)$')
plt.plot(x, np.cos(x), 'k:', label='$cos(x)$')
plt.ylabel('$x^2$ and $x^3$')
plt.xlabel('x')
plt.xlim(-3, 3)
plt.ylim(-1, 1)
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### subplot을 사용하여 여러 그래프 한번에 그리기

# %%
# 2 x 1 figure 매트릭스에 그래프 그리기

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.figure(figsize=(12, 8))

plt.subplot(211) # 도화지 나누기 2행 1열 그래프의 첫번째
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

plt.subplot(212) # 도화지 나누기 2행 1열 그래프의 두번째
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout() # 여백줄이기
plt.show()

# %%
# 2 x 2 figure 매트릭스에 위에 그려진 제곱, 세제곱, sin, cos 그래프 나누기

plt.figure(figsize=(12, 8))
#plt.figure(figsize=(10, 7))
#plt.title('$x^2$ and $x^3$')
x = np.linspace(-10, 10, 300)
# plt.plot(x, x*x, label='$x^2$')
# plt.plot(x, x*x*x, 'r--', label='$x^3$')
# plt.plot(x, np.sin(x), 'g:', label='$sin(x)$')
# plt.plot(x, np.cos(x), 'k:', label='$cos(x)$')
# plt.ylabel('$x^2$ and $x^3$')
# plt.xlabel('x')
# plt.xlim(-3, 3)
# plt.ylim(-1, 1)
# plt.legend(loc='best')
# plt.show()

for i in range(10):
    plt.subplot(2, 2, i) # 도화지를 나누는 함수 괄호안에 (도화지의 행, 도화지 열, 순서) 
    for item in df:
        plt.plot(item)

plt.subplot(221) # 도화지를 나누는 함수 괄호안에 (도화지의 행, 도화지 열, 순서) 
plt.title('$x^2$')
plt.plot(x, x*x, label='$x^2$')
plt.legend()

plt.subplot(222)
plt.title('$x^3$')
plt.plot(x, x*x*x, 'r--', label='$x^3$')
plt.legend()

plt.subplot(223)
plt.title('$sin(x)$')
plt.plot(x, np.sin(x), 'g:', label='$sin(x)$')
plt.legend()

plt.subplot(224)
plt.title('$cos(x)$')
plt.plot(x, np.cos(x), 'k:', label='$cos(x)$')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### bar plot
# > 전통적으로 bar plot은 범주형 데이터(구간이 나누어져 있는) 데이터의 갯수, 빈도를 나타내는 데 쓰였습니다.
# 지난 시간 학습한 loan 데이터의 신용등급을 bar plot으로 그려보겠습니다.

# %%
# loan1.csv 파일 불러들이기
df = pd.read_csv('./data/loan1.csv')

# %%
df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      10000        10000          10000.0   36 months
# 1 NaN        NaN       3500         3500           3500.0   36 months
# 2 NaN        NaN       5000         5000           5000.0   36 months
# 3 NaN        NaN      14000        14000          14000.0   36 months
# 4 NaN        NaN       5000         5000           5000.0   36 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0      9.44       320.05     B        B1  ...                            NaN
# 1     10.42       113.63     B        B3  ...                            NaN
# 2     13.59       169.90     C        C2  ...                            NaN
# 3     10.91       457.75     B        B4  ...                            NaN
# 4     13.59       169.90     C        C2  ...                            NaN
#
#   hardship_last_payment_amount disbursement_method  debt_settlement_flag  \
# 0                          NaN                Cash                     N
# 1                          NaN                Cash                     N
# 2                          NaN                Cash                     N
# 3                          NaN                Cash                     N
# 4                          NaN                Cash                     N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#   settlement_amount  settlement_percentage  settlement_term
# 0               NaN                    NaN              NaN
# 1               NaN                    NaN              NaN
# 2               NaN                    NaN              NaN
# 3               NaN                    NaN              NaN
# 4               NaN                    NaN              NaN
#
# [5 rows x 145 columns]

# %%
# 범주형 데이터(카테고리컬 데이터)
df['grade'].value_counts()
# Out:
# B    15746
# C    13705
# A    10800
# D     7461
# E     1793
# F      388
# G      107
# Name: grade, dtype: int64

# %%
# 세부신용등급 각 항목별 갯수세기
df['sub_grade'].value_counts().sort_index()
# Out:
# A1    1463
# A2    1987
# A3    2440
# A4    2545
# A5    2365
# B1    3343
# B2    3278
# B3    3396
# B4    2386
# B5    3343
# C1    3106
# C2    2858
# C3    2778
# C4    2507
# C5    2456
# D1    1810
# D2    1591
# D3    1487
# D4    1363
# D5    1210
# E1     256
# E2     483
# E3     411
# E4     328
# E5     315
# F1     196
# F2      52
# F3      57
# F4      42
# F5      41
# G1      79
# G2       9
# G3       4
# G4      10
# G5       5
# Name: sub_grade, dtype: int64

# %%
# 세부신용등급 bar plot
plt.figure(figsize=(12, 6))
plt.bar(df['sub_grade'].value_counts().sort_index().index, df['sub_grade'].value_counts().sort_index().values)
# Out:
# <BarContainer object of 35 artists>

# %%
# 세부신용등급 barh plot
plt.figure(figsize=(12, 6))
plt.barh(df['sub_grade'].value_counts().sort_index(ascending=False).index, df['sub_grade'].value_counts().sort_index(ascending=False).values)
# Out:
# <BarContainer object of 35 artists>

# %% [markdown]
# ### 히스토그램
# > 데이터의 분포를 확인하고자 할 때 많이 사용하는 시각화 방법.
# 전체 데이터 구간 중 특정 구간에 속한 데이터의 빈도수를 계산하여 구간에 매칭시킴
# 데이터 구간별 밀도를 확인할 수 있다.

# %%
# 대출금액분포 hist plot으로 확인
plt.figure(figsize=(12, 6))
plt.hist(df['loan_amnt'], bins=1000);

# %% [markdown]
# ### scatter plot
# > 2개 혹은 2개 이상의 변수간의 관계를 확인하고자 할 때 많이 사용하는 시각화 방법.
# X축과 Y축에 각각의 변수 데이터를 위치시키고 포인트들이 자리한 평면상의 분포를 통해 상관관계를 파악할 수 있다.

# %%
# 각각의 변수와 우리가 보고자 하는 값과의 관계를 볼 때 가장 많이 사용합니다.
# loan_amnt, installment
plt.figure(figsize=(12, 6))
plt.xlabel('loan_amnt')
plt.ylabel('installment')
plt.scatter(df['loan_amnt'], df['installment'])
plt.show()

# %%
df.columns[:30]
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record'],
#       dtype='object')

# %%
# int_rate에 해당하는 인사이트를 얻고싶다
plt.figure(figsize=(12, 6))
# plt.xlabel('loan_amnt')
# plt.ylabel('installment')
plt.scatter(df['annual_inc'], df['int_rate'])
plt.xlim([0, 20000])
plt.show()

# %%
df['loan_amnt'].plot.hist()

# %% [markdown]
# ## matplotlib 예제 살펴보기

# %%
import matplotlib.pyplot as plt
import matplotlib.tri as tri
import numpy as np

# First create the x and y coordinates of the points.
n_angles = 36
n_radii = 8
min_radius = 0.25
radii = np.linspace(min_radius, 0.95, n_radii)

angles = np.linspace(0, 2 * np.pi, n_angles, endpoint=False)
angles = np.repeat(angles[..., np.newaxis], n_radii, axis=1)
angles[:, 1::2] += np.pi / n_angles

x = (radii * np.cos(angles)).flatten()
y = (radii * np.sin(angles)).flatten()

# Create the Triangulation; no triangles so Delaunay triangulation created.
triang = tri.Triangulation(x, y)

# Mask off unwanted triangles.
triang.set_mask(np.hypot(x[triang.triangles].mean(axis=1),
                         y[triang.triangles].mean(axis=1))
                < min_radius)
fig1, ax1 = plt.subplots()
ax1.set_aspect('equal')
ax1.triplot(triang, 'bo-', lw=1)
ax1.set_title('triplot of Delaunay triangulation')
# Out:
# Text(0.5, 1.0, 'triplot of Delaunay triangulation')

# %%
from cycler import cycler
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# Define a list of markevery cases and color cases to plot
cases = [None,
         8,
         (30, 8),
         [16, 24, 30],
         [0, -1],
         slice(100, 200, 3),
         0.1,
         0.3,
         1.5,
         (0.0, 0.1),
         (0.45, 0.1)]

colors = ['#1f77b4',
          '#ff7f0e',
          '#2ca02c',
          '#d62728',
          '#9467bd',
          '#8c564b',
          '#e377c2',
          '#7f7f7f',
          '#bcbd22',
          '#17becf',
          '#1a55FF']

# Configure rcParams axes.prop_cycle to simultaneously cycle cases and colors.
mpl.rcParams['axes.prop_cycle'] = cycler(markevery=cases, color=colors)

# Create data points and offsets
x = np.linspace(0, 2 * np.pi)
offsets = np.linspace(0, 2 * np.pi, 11, endpoint=False)
yy = np.transpose([np.sin(x + phi) for phi in offsets])

# Set the plot curve with markers and a title
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.6, 0.75])

for i in range(len(cases)):
    ax.plot(yy[:, i], marker='o', label=str(cases[i]))
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.title('Support for axes.prop_cycle cycler with markevery')

plt.show()

# %%
# %matplotlib notebook
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook # 3D plot을 인터랙티브하게 움직일 수 있도록 주피터노트북 설정
# %matplotlib inline # plot크기를 주피터 노트북에 알맞게(크기에 벗어나지 않게 그려줌)

plt.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')

# Prepare arrays x, y, z
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)

ax.plot(x, y, z, label='parametric curve')
ax.legend()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="431.818172458775">

# %% [markdown]
# ## **seaborn**
# > matplotlib와 마찬가지로 많은 데이터분석가들이 주로 사용하는 시각화 라이브러리
# matplotlib에 비해 기본적인 시각적 심미성이 뛰어나다
# matplotlib에서 지원하지 않는 다양한 형태의 시각화도구를 제공한다.

# %%
# 패키지 설치
# !pip install seaborn

# %%
# 패키지 import
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# ### barplot

# %%
plt.figure(figsize=(12, 6))
sns.barplot(df['sub_grade'].value_counts().sort_index().index, df['sub_grade'].value_counts().sort_index().values)
plt.show()

# %% [markdown]
# ### countplot

# %%
# 쉬운 방법으로 barplot 구현이 가능하다.
plt.figure(figsize=(12, 6))
sns.countplot(df['grade'])
plt.show()

# %% [markdown]
# ### distplot(히스토그램)

# %%
plt.figure(figsize=(12, 6))
sns.distplot(df['loan_amnt'])
plt.show()

# %% [markdown]
# ### scatterplot

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(df['loan_amnt'], df['installment'])
plt.show()

# %% [markdown]
# ### boxplot

# %%
# 굉장히 많이 사용
# 각각의 box하나당 해당 데이터의 사분위수, 중앙값, 최대, 최소값을 표기한다.
plt.figure(figsize=(12, 6))
sns.boxplot(df['grade'], df['int_rate'])
plt.show()

# %% [markdown]
# ### jointplot

# %%
# loan_amnt, int_rate의 scatter plot + hist plot의 결합형태인 joint plot
plt.figure(figsize=(12, 6))
sns.jointplot(df['loan_amnt'], df['installment'], kind='kde')
plt.show()

# %% [markdown]
# ### pairplot

# %%
# 각 컬럼간 모든 scatter plot을 그리는 pairplot
pair_df = df[['loan_amnt', 'funded_amnt', 'int_rate', 'installment']]
plt.figure(figsize=(12, 6))
sns.pairplot(pair_df)
plt.show()
